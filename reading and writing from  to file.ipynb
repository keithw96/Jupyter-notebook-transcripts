# %%
##Writing to File
with open("test.txt", "w") as text_file:
    text_file.write("I am writing a string to text")
    
##Reading from text file and assigning to variable.
with open("pooh.txt", errors = 'ignore') as text_file:
    rawData = text_file.read()
    
rawData
##Splitting strings in to individual words.
words = rawData.split()
##Get a specific word from a string (index)
word = words[4]
print(word)
print(word[0])

print(len(word))

for a in words:
    if len(a) >= 7:
        print(a)
# Out:
# INTRODUCED
# I
# 10
# INTRODUCED
# WINNIE-THE-POOH
# STORIES
# downstairs
# Christopher
# downstairs,
# sometimes
# another
# bumping
# perhaps
# Anyhow,
# bottom,
# introduced
# Winnie-the-Pooh.
# thought
# Christopher
# Winnie?"
# don't."
# said--"
# Winnie-ther-Pooh.
# means?"
# quickly;
# because
# explanation
# Sometimes
# Winnie-the-Pooh
# downstairs,
# sometimes
# quietly
# evening--
# story?"
# Christopher
# story?"
# sweetly
# Winnie-the-Pooh
# suppose
# could,"
# stories
# himself.
# Because
# sweetly?"
# Friday,
# Winnie-the-Pooh
# himself
# Sanders.
# Christopher
# letters,
# "Winnie-the-Pooh
# Christopher
# walking,
# forest,
# oak-tree,
# buzzing-noise.
# Winnie-the-Pooh
# between
# himself:
# buzzing-noise
# something.
# buzzing-noise
# buzzing
# buzzing,
# without
# meaning
# something.
# there's
# buzzing-noise,
# somebody's
# buzzing-noise,
# buzzing-noise
# because
# thought
# another
# honey."
# climbed
# climbed
# climbed
# climbed
# himself.
# climbed
# ...
